# %%
#!pip install matplotlib_inline

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('retina', quality=100)
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import MinMaxScaler

# %%
# Load datasets
nyc_category_counts = pd.read_csv('nyc_category_counts.csv')
nyc_category_frequencies = pd.read_csv('nyc_category_frequencies.csv')
nyc_health_borough = pd.read_csv('nyc_health_borough.csv')

# %%
# Set copies not to change original dataframe
nyc_health_boroughDBS = nyc_health_borough.copy()
nyc_health_boroughDBS.head()
# Out:
#                                   Venue                  Category  Latitude_x  \
# 0      Cuomo Family Chiropractic Center              Chiropractor   40.856519
# 1  Companion Angels Home Care Solutions  Home Health Care Service   40.855880
# 2                                    Ww              Nutritionist   40.859098
# 3                  Marrone Chiropractic              Chiropractor   40.864864
# 4                 Williamsbridge Dental                   Dentist   40.863214
#
#    Longitude_x Neighborhood    ZIP Borough  Longitude_y  Latitude_y
# 0   -73.856269     Allerton  10461   Bronx   -73.859319   40.865788
# 1   -73.855896     Allerton  10461   Bronx   -73.859319   40.865788
# 2   -73.856801     Allerton  10469   Bronx   -73.859319   40.865788
# 3   -73.859463     Allerton  10469   Bronx   -73.859319   40.865788
# 4   -73.858484     Allerton  10469   Bronx   -73.859319   40.865788

# %%
# Isolate Category, Neighborhood Lat and Lon for plotting purposes
df = nyc_health_boroughDBS[['Category', 'Longitude_x', 'Latitude_x']]
df.head()
# Out:
#                    Category  Longitude_x  Latitude_x
# 0              Chiropractor   -73.856269   40.856519
# 1  Home Health Care Service   -73.855896   40.855880
# 2              Nutritionist   -73.856801   40.859098
# 3              Chiropractor   -73.859463   40.864864
# 4                   Dentist   -73.858484   40.863214

# %% [markdown]
# ## Define Plot Clusters Function using DBSCANS

# %%
def plot_clusters(X,y_res, plt_cluster_centers = False):
    """
    Creates a scatter plot and assigns colours to data point according to 
    clustering labels.
    """
    X_centroids = []
    Y_centroids = []

    for cluster in set(y_res):
        x = X[y_res == cluster,0]
        y = X[y_res == cluster,1]
        X_centroids.append(np.mean(x))
        Y_centroids.append(np.mean(y))

        plt.scatter(x,
                    y,
                    s=50,
                    marker='s',
                    label=f'cluster {cluster}')

    if plt_cluster_centers:
        plt.scatter(X_centroids,
                    Y_centroids,
                    marker='*',
                    c='red',
                    s=250,
                    label='centroids')
    
    plt.title('DBScans Facility Location Clusters')
    plt.ylabel('Latitude', fontsize=12)
    plt.xlabel('Longitude', fontsize=12)
    
    plt.grid()
    plt.show()
    plt.savefig('DBScans_Fac_Loc_Clusters.png')

# %% [markdown]
# ## Clustering Care Facilities in NYC

# %%
y_df = df['Category'] # Set y df to category
x_df = df.drop(['Category'], axis=1) # set x df to lat lon of all care facility venues
X = x_df.to_numpy() # convert x df into 2-dimensional numpy array

# %%
plt.scatter(X[:,0], X[:,1]) # Plot lat lon of all care facility venues

plt.title('Care Facility Locations')
plt.xlabel('Longitude', fontsize=12)
plt.ylabel('Latitude', fontsize=12)

plt.show()
#plt.savefig('Care_Facility_Venues.png')

# %% [markdown]
# ## Optimal Epsilon

# %%
# Nearest neighbor method to determine the optimal epsilon score
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(X)
distances, indices = nbrs.kneighbors(X)

# %%
# plot nearest neighbor method to visualize optimal epsilon
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.title('Epsilon Optimization for Care Facility Location Clusters')
plt.ylabel('Epsilon Score', fontsize=12)
plt.plot(distances)
#plt.savefig('Epsilon_Optimization_for_Care_Facility_Location_Clusters.png')

# %%
# Set db with DBSCANS optimal parameters
db = DBSCAN(eps=0.007,
            min_samples=4,
            metric='euclidean')

# %%
# Fit and predict the optimal parameters over lat lon of dentist offices
y_db = db.fit_predict(X)

plot_clusters(X,y_db)
