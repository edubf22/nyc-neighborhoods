# %% [markdown]
# ## Data Acquisition

# %%
import json

# %%
with open('nyc_geo.json') as f:
    nyc_geo_json = json.load(f)

# %%
nyc_geo_json['features'][0]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.1',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.84720052054902, 40.89470517661]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Wakefield',
#   'stacked': 1,
#   'annoline1': 'Wakefield',
#   'annoline2': None,
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.84720052054902,
#    40.89470517661,
#    -73.84720052054902,
#    40.89470517661]}}

# %%
from pandas import json_normalize  
features = json_normalize(nyc_geo_json, record_path ='features')
features.head()
# Out:
#       type                id geometry_name geometry.type  \
# 0  Feature  nyu_2451_34572.1          geom         Point
# 1  Feature  nyu_2451_34572.2          geom         Point
# 2  Feature  nyu_2451_34572.3          geom         Point
# 3  Feature  nyu_2451_34572.4          geom         Point
# 4  Feature  nyu_2451_34572.5          geom         Point
#
#                        geometry.coordinates properties.name  \
# 0      [-73.84720052054902, 40.89470517661]       Wakefield
# 1   [-73.82993910812398, 40.87429419303012]      Co-op City
# 2  [-73.82780644716412, 40.887555677350775]     Eastchester
# 3   [-73.90564259591682, 40.89543742690383]       Fieldston
# 4   [-73.9125854610857, 40.890834493891305]       Riverdale
#
#    properties.stacked properties.annoline1 properties.annoline2  \
# 0                   1            Wakefield                 None
# 1                   2                Co-op                 City
# 2                   1          Eastchester                 None
# 3                   1            Fieldston                 None
# 4                   1            Riverdale                 None
#
#   properties.annoline3  properties.annoangle properties.borough  \
# 0                 None                   0.0              Bronx
# 1                 None                   0.0              Bronx
# 2                 None                   0.0              Bronx
# 3                 None                   0.0              Bronx
# 4                 None                   0.0              Bronx
#
#                                      properties.bbox
# 0  [-73.84720052054902, 40.89470517661, -73.84720...
# 1  [-73.82993910812398, 40.87429419303012, -73.82...
# 2  [-73.82780644716412, 40.887555677350775, -73.8...
# 3  [-73.90564259591682, 40.89543742690383, -73.90...
# 4  [-73.9125854610857, 40.890834493891305, -73.91...

# %%
features['properties.name'].value_counts(), features['properties.annoline1'].value_counts()
# Out:
# (Bay Terrace      2
#  Murray Hill      2
#  Chelsea          2
#  Sunnyside        2
#  Wakefield        1
#                  ..
#  Fort Hamilton    1
#  Ocean Parkway    1
#  South Side       1
#  North Side       1
#  Fox Hills        1
#  Name: properties.name, Length: 302, dtype: int64,
#  East                5
#  New                 5
#  Sunnyside           3
#  Jamaica             3
#  West                3
#                     ..
#  Central             1
#  Yorkville           1
#  Lenox               1
#  Roosevelt Island    1
#  Fox                 1
#  Name: properties.annoline1, Length: 263, dtype: int64)

# %%
features['geometry.coordinates'].value_counts(), features['properties.bbox'].value_counts()
# Out:
# ([-73.84720052054902, 40.89470517661]        1
#  [-74.1071817826561, 40.63187892654607]      1
#  [-74.11918058534842, 40.61333593766742]     1
#  [-74.17464532993542, 40.63968297845542]     1
#  [-74.15008537046981, 40.632546390481124]    1
#                                             ..
#  [-73.93690027985234, 40.85190252555305]     1
#  [-73.99427936255978, 40.71561842231432]     1
#  [-74.03197914537984, 40.61476812694226]     1
#  [-73.96836678035541, 40.61305976667942]     1
#  [-74.08173992211962, 40.61731079252983]     1
#  Name: geometry.coordinates, Length: 306, dtype: int64,
#  [-73.84720052054902, 40.89470517661, -73.84720052054902, 40.89470517661]            1
#  [-74.1071817826561, 40.63187892654607, -74.1071817826561, 40.63187892654607]        1
#  [-74.11918058534842, 40.61333593766742, -74.11918058534842, 40.61333593766742]      1
#  [-74.17464532993542, 40.63968297845542, -74.17464532993542, 40.63968297845542]      1
#  [-74.15008537046981, 40.632546390481124, -74.15008537046981, 40.632546390481124]    1
#                                                                                     ..
#  [-73.93690027985234, 40.85190252555305, -73.93690027985234, 40.85190252555305]      1
#  [-73.99427936255978, 40.71561842231432, -73.99427936255978, 40.71561842231432]      1
#  [-74.03197914537984, 40.61476812694226, -74.03197914537984, 40.61476812694226]      1
#  [-73.96836678035541, 40.61305976667942, -73.96836678035541, 40.61305976667942]      1
#  [-74.08173992211962, 40.61731079252983, -74.08173992211962, 40.61731079252983]      1
#  Name: properties.bbox, Length: 306, dtype: int64)

# %% [markdown]
# ## Data Organization
# #### Parse the json nyc_geo.json into the dataframe with the following columns:
#
# - Borough
# - Neighborhood
# - Latitude
# - Longitude

# %%
import pandas as pd
LatLon = pd.DataFrame(features['geometry.coordinates'].to_list(), columns=['Longitude', 'Latitude'])
LatLon.head()
# Out:
#    Longitude   Latitude
# 0 -73.847201  40.894705
# 1 -73.829939  40.874294
# 2 -73.827806  40.887556
# 3 -73.905643  40.895437
# 4 -73.912585  40.890834

# %%
df1=features[['properties.name', 'properties.borough']]
df1.head()
# Out:
#   properties.name properties.borough
# 0       Wakefield              Bronx
# 1      Co-op City              Bronx
# 2     Eastchester              Bronx
# 3       Fieldston              Bronx
# 4       Riverdale              Bronx

# %%
dataFrames=[df1, LatLon]
nyc_df = pd.concat(dataFrames, axis=1)
nyc_df = nyc_df.rename(columns={'properties.name' : 'Neighborhood', 'properties.borough': 'Borough'})
nyc_df.head()
# Out:
#   Neighborhood Borough  Longitude   Latitude
# 0    Wakefield   Bronx -73.847201  40.894705
# 1   Co-op City   Bronx -73.829939  40.874294
# 2  Eastchester   Bronx -73.827806  40.887556
# 3    Fieldston   Bronx -73.905643  40.895437
# 4    Riverdale   Bronx -73.912585  40.890834

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(nyc_df['Borough'].unique()),
        nyc_df.shape[0]))
# Out:
# The dataframe has 5 boroughs and 306 neighborhoods.

# %% [markdown]
# ### Dealing with Duplicates

# %% [markdown]
# ##### The following neighborhoods share a name with another neighborhood in a separate borough.

# %%
nyc_doubles = nyc_df['Neighborhood'].value_counts()
nyc_doubles[nyc_doubles>1]
# Out:
# Bay Terrace    2
# Murray Hill    2
# Chelsea        2
# Sunnyside      2
# Name: Neighborhood, dtype: int64

# %%
nyc_df[nyc_df['Neighborhood'] == 'Chelsea']
# Out:
#     Neighborhood        Borough  Longitude   Latitude
# 116      Chelsea      Manhattan -74.003116  40.744035
# 244      Chelsea  Staten Island -74.189560  40.594726

# %% [markdown]
# ##### We will parse through the dataframe to place the borough name at the end of the neighborhood name so as to distinguish between them.

# %%
for i in range(nyc_df.shape[0]):
    nyc_in = nyc_df.loc[i, 'Neighborhood']
    if nyc_df[nyc_df['Neighborhood'] == nyc_in].shape[0] > 1:
        nyc_in1 = nyc_df[nyc_df['Neighborhood'] == nyc_in].index.tolist()
        for j in nyc_in1:
            nyc_in2 = nyc_df.loc[j, 'Borough']
            nyc_df.loc[j, 'Neighborhood'] = nyc_in + ', ' + nyc_in2

# %%
nyc_df[nyc_df['Neighborhood'].str.startswith('Chelsea')]
# Out:
#                Neighborhood        Borough  Longitude   Latitude
# 116      Chelsea, Manhattan      Manhattan -74.003116  40.744035
# 244  Chelsea, Staten Island  Staten Island -74.189560  40.594726

# %%
nyc_df[nyc_df['Neighborhood'].str.startswith('Sunnyside')]
# Out:
#                  Neighborhood        Borough  Longitude   Latitude
# 140         Sunnyside, Queens         Queens -73.926916  40.740176
# 220  Sunnyside, Staten Island  Staten Island -74.097126  40.612760
# 277         Sunnyside Gardens         Queens -73.918193  40.745652

# %%
nyc_df[nyc_df['Neighborhood'].str.startswith('Murray Hill')]
# Out:
#                Neighborhood    Borough  Longitude   Latitude
# 115  Murray Hill, Manhattan  Manhattan -73.978332  40.748303
# 180     Murray Hill, Queens     Queens -73.812763  40.764126

# %%
nyc_df[nyc_df['Neighborhood'].str.startswith('Bay Terrace')]
# Out:
#                    Neighborhood        Borough  Longitude   Latitude
# 175         Bay Terrace, Queens         Queens -73.776802  40.782843
# 235  Bay Terrace, Staten Island  Staten Island -74.139166  40.553988

# %%
nyc_df.isnull().sum()
# Out:
# Neighborhood    0
# Borough         0
# Longitude       0
# Latitude        0
# dtype: int64

# %%
nyc_df.to_csv('nyc_df.csv')

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import folium # map rendering library
import matplotlib.pyplot as plt

address = 'New York City, NY'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10, 
                         min_zoom=9, max_zoom=15)

# add markers to map
for lat, lon, borough, neighborhood in zip(nyc_df['Latitude'], 
                                           nyc_df['Longitude'], 
                                           nyc_df['Borough'], 
                                           nyc_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=3,
        popup=label,
        weight=2,
        color='#333333',
        fill=True,
        fill_color='#ffb300',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d72d74034992df0356c2eeb5860be23 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d72d74034992df0356c2eeb5860be23&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8d72d74034992df0356c2eeb5860be23 = L.map(
#                 &quot;map_8d72d74034992df0356c2eeb5860be23&quot;,
#                 {
#                     center: [40.7127281, -74.0060152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6b927d8f0c9d44f70064fecf48aa7cc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 15, &quot;maxZoom&quot;: 15, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8d72d74034992df0356c2eeb5860be23);
#
#
#             var circle_marker_7ddadf3243bb58fa3c2da0ef00d31bbc = L.circleMarker(
#                 [40.89470517661, -73.84720052054902],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#333333&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffb300&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_8d72d74034992df0356c2eeb5860be23);
#
#
#         var popup_1ed57944bf83b8558562902fe1e64615 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_880ba0ad649e6623bcf8fb162cc60488 = $(`&lt;div id=&quot;html_880ba0ad649e6623bcf8fb162cc60488&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wakefield, Bronx&lt;/div&gt;`)[0];
#                 popup_1ed57944bf83b8558562902fe1e64615.setContent(html_880ba0ad649e6623bcf8fb162cc60488);
#
#
#
#         circle_marker_7ddadf3243bb58fa3c2da0ef00d31bbc.bindPopup(popup_1ed57944bf83b8558562902fe1e64615)
#         ;
#
#
#
#
#             var circle_marker_ebd4c166a6913a4b2ca97337cd9b47e2 = L.circleMarker(
#                 [40.87429419303012, -73.82993910812398],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#333333&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffb300&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_8d72d74034992df0356c2eeb5860be23);
#
#
#         var popup_b47658531f5b9172297aced7e7cbc43f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87b98ad9287db778c70375cf4bfe61e9 = $(`&lt;div id=&quot;html_87b98ad9287db778c70375cf4bfe61e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Co-op City, Bronx&lt;/div&gt;`)[0];
#                 popup_b47658531f5b9172297aced7e7cbc43f.setContent(html_87b98ad9287db778c70375cf4bfe61e9);
#
#
#
#         circle_marker_ebd4c166a6913a4b2ca97337cd9b47e2.bindPopup(popup_b47658531f5b9172297aced7e7cbc43f)
#         ;
#
#
#
#
#             var circle_marker_cda9f4867cfcdc312350cbdfb786a021 = L.circleMarker(
#                 [40.887555677350775, -73.82780644716412],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#333333&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffb300&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_8d72d74034992df0356c2eeb5860be23);
#
#
#         var popup_670ba67b7be031cb63dc3a3d6185187b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75670c3104b95bff360456cf1247f4d6 = $(`&lt;div id=&quot;html_75670c3104b95bff360456cf1247f4d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eastchester, Bronx&lt;/div&gt;`)[0];
#                 popup_670ba67b7be031cb63dc3a3d6185187b.setContent(html_75670c3104b95bff360456cf1247f4d6);
#
#
#
#         circle_marker_cda9f4867cfcdc312350cbdfb786a021.bindPopup(popup_670ba67b7be031cb63dc3a3d6185187b)
#         ;
#
#
#
#
#             var circle_marker_1bc1e0d168026a7e211863d500d01d1a = L.circleMarker(
#                 [40.89543742690383, -73.90564259591682],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#333333&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffb300&

# %% [markdown]
# ### Downloading and Parsing the NYC Housing Mean Prices DataFrame

# %%
nyc_housing = pd.read_excel('nyc_housing_mean_prices.xlsx')
nyc_housing.head()
# Out:
#          neighborhood  studio  Unnamed: 2      neighborhood.1 1_bedroom  \
# 0     Upper West Side  $1,975         NaN     Upper West Side    $2,750
# 1  Bedford-Stuyvesant  $1,650         NaN  Bedford-Stuyvesant    $1,975
# 2            Bushwick  $1,731         NaN            Bushwick    $2,150
# 3     Upper East Side  $1,898         NaN     Upper East Side    $2,395
# 4        Williamsburg  $2,491         NaN        Williamsburg    $2,500
#
#    Unnamed: 5      neighborhood.2 2_bedroom
# 0         NaN     Upper West Side    $4,350
# 1         NaN  Bedford-Stuyvesant    $2,200
# 2         NaN            Bushwick    $2,100
# 3         NaN     Upper East Side    $3,295
# 4         NaN        Williamsburg    $2,584

# %%
nyc_housing.shape
# Out:
# (205, 8)

# %%
nyc_housing.isnull().sum()
# Out:
# neighborhood       68
# studio             68
# Unnamed: 2        205
# neighborhood.1     11
# 1_bedroom          11
# Unnamed: 5        205
# neighborhood.2      0
# 2_bedroom           0
# dtype: int64

# %%
nyc_housing = nyc_housing.drop(['Unnamed: 2', 'Unnamed: 5'], axis=1)

# %%
nyc_housing['studio'] = nyc_housing['studio'].str.replace('$', '')
nyc_housing['1_bedroom'] = nyc_housing['1_bedroom'].str.replace('$', '')
nyc_housing['2_bedroom'] = nyc_housing['2_bedroom'].str.replace('$', '')
nyc_housing.head()
# Out:
# /var/folders/cl/dg9768bj6ys0prn_4p_bbftw0000gn/T/ipykernel_10605/1623327326.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   nyc_housing['studio'] = nyc_housing['studio'].str.replace('$', '')
# /var/folders/cl/dg9768bj6ys0prn_4p_bbftw0000gn/T/ipykernel_10605/1623327326.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   nyc_housing['1_bedroom'] = nyc_housing['1_bedroom'].str.replace('$', '')
# /var/folders/cl/dg9768bj6ys0prn_4p_bbftw0000gn/T/ipykernel_10605/1623327326.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   nyc_housing['2_bedroom'] = nyc_housing['2_bedroom'].str.replace('$', '')
#          neighborhood studio      neighborhood.1 1_bedroom  \
# 0     Upper West Side  1,975     Upper West Side     2,750
# 1  Bedford-Stuyvesant  1,650  Bedford-Stuyvesant     1,975
# 2            Bushwick  1,731            Bushwick     2,150
# 3     Upper East Side  1,898     Upper East Side     2,395
# 4        Williamsburg  2,491        Williamsburg     2,500
#
#        neighborhood.2 2_bedroom
# 0     Upper West Side     4,350
# 1  Bedford-Stuyvesant     2,200
# 2            Bushwick     2,100
# 3     Upper East Side     3,295
# 4        Williamsburg     2,584

# %%
nyc_housing['studio']=nyc_housing['studio'].str.replace(',', '')

# %%
nyc_housing['1_bedroom']=nyc_housing['1_bedroom'].str.replace(',', '')
nyc_housing['2_bedroom']=nyc_housing['2_bedroom'].str.replace(',', '')

# %%
nyc_housing['studio']=nyc_housing['studio'].astype(float)
nyc_housing['1_bedroom']=nyc_housing['1_bedroom'].astype(float)
nyc_housing['2_bedroom']=nyc_housing['2_bedroom'].astype(float)
nyc_housing.head(70)
# Out:
#           neighborhood  studio      neighborhood.1  1_bedroom  \
# 0      Upper West Side  1975.0     Upper West Side     2750.0
# 1   Bedford-Stuyvesant  1650.0  Bedford-Stuyvesant     1975.0
# 2             Bushwick  1731.0            Bushwick     2150.0
# 3      Upper East Side  1898.0     Upper East Side     2395.0
# 4         Williamsburg  2491.0        Williamsburg     2500.0
# ..                 ...     ...                 ...        ...
# 65         Bensonhurst  4200.0         Bensonhurst     1500.0
# 66   Kew Gardens Hills  1450.0   Kew Gardens Hills     1699.0
# 67            Glendale  1400.0            Glendale     1675.0
# 68       Richmond Hill  1675.0      Middle Village     1800.0
# 69             Midwood  2200.0       Richmond Hill     1695.0
#
#         neighborhood.2  2_bedroom
# 0      Upper West Side     4350.0
# 1   Bedford-Stuyvesant     2200.0
# 2             Bushwick     2100.0
# 3      Upper East Side     3295.0
# 4         Williamsburg     2584.0
# ..                 ...        ...
# 65         Bensonhurst     1795.0
# 66   Kew Gardens Hills     2100.0
# 67            Glendale     2000.0
# 68      Middle Village     2100.0
# 69       Richmond Hill     1980.0
#
# [70 rows x 6 columns]

# %%
nyc_housing.groupby('neighborhood').sum()
# Out:
#                      studio  1_bedroom  2_bedroom
# neighborhood
# Allerton             1450.0     1590.0     2200.0
# Astoria              1575.0     1875.0     2200.0
# Auburndale           1795.0     1555.0     2888.0
# Bath Beach           3000.0     1700.0     1900.0
# Battery Park City    2200.0     2733.0     4431.0
# ...                     ...        ...        ...
# Westchester Village  1100.0     1625.0     2200.0
# Williamsburg         2491.0     2500.0     2584.0
# Windsor Terrace      1900.0     2325.0     2800.0
# Woodhaven            1627.0     1550.0     2295.0
# Woodside             1550.0     1700.0     2173.0
#
# [137 rows x 3 columns]

# %%
nyc_housing.set_index('neighborhood.2').stack().droplevel(1).reset_index()
# Out:
#          neighborhood.2                0
# 0       Upper West Side  Upper West Side
# 1       Upper West Side           1975.0
# 2       Upper West Side  Upper West Side
# 3       Upper West Side           2750.0
# 4       Upper West Side           4350.0
# ..                  ...              ...
# 862  Van Cortlandt Park           1983.0
# 863   Castleton Corners           1400.0
# 864  Brooklyn Navy Yard           5345.0
# 865    Travis - Chelsea           1800.0
# 866            Longwood           1377.0
#
# [867 rows x 2 columns]

# %% [markdown]
# #### The shape and neighborhood columns of this dataframe will not match either the average prices data set, nor the original dataframe from NYC Json. We will re-visit this.

# %%
df_neighborhood = nyc_housing[['neighborhood','studio', '1_bedroom', '2_bedroom']]

# %%
df_neighborhood = df_neighborhood.dropna(subset = ['neighborhood'])
df_neighborhood
# Out:
#                      neighborhood  studio  1_bedroom  2_bedroom
# 0                 Upper West Side  1975.0     2750.0     4350.0
# 1              Bedford-Stuyvesant  1650.0     1975.0     2200.0
# 2                        Bushwick  1731.0     2150.0     2100.0
# 3                 Upper East Side  1898.0     2395.0     3295.0
# 4                    Williamsburg  2491.0     2500.0     2584.0
# ..                            ...     ...        ...        ...
# 132            University Heights  1300.0     1700.0     2645.0
# 133                      Foxhurst   947.0     1500.0     2198.0
# 134  Flushing Meadows-Corona Park  1650.0     1350.0     2350.0
# 135            Van Cortlandt Park  1400.0     1575.0     1750.0
# 136            Brooklyn Navy Yard  3000.0     1625.0     2100.0
#
# [137 rows x 4 columns]

# %%
df_neighborhood1 = nyc_housing[['neighborhood.1','studio', '1_bedroom', '2_bedroom']]
df_neighborhood1 = df_neighborhood1.dropna(subset = ['neighborhood.1'])
df_neighborhood1 = df_neighborhood1.rename(columns={'neighborhood.1': 'neighborhood'})
df_neighborhood1
# Out:
#                      neighborhood  studio  1_bedroom  2_bedroom
# 0                 Upper West Side  1975.0     2750.0     4350.0
# 1              Bedford-Stuyvesant  1650.0     1975.0     2200.0
# 2                        Bushwick  1731.0     2150.0     2100.0
# 3                 Upper East Side  1898.0     2395.0     3295.0
# 4                    Williamsburg  2491.0     2500.0     2584.0
# ..                            ...     ...        ...        ...
# 189  Flushing Meadows-Corona Park     NaN     1975.0     1475.0
# 190                 Manor Heights     NaN     1200.0     1900.0
# 191                    Blissville     NaN     1600.0     1700.0
# 192            Van Cortlandt Park     NaN     1500.0     1575.0
# 193            Brooklyn Navy Yard     NaN     3395.0     1750.0
#
# [194 rows x 4 columns]

# %%
df_neighborhood2 = nyc_housing[['neighborhood.2','studio', '1_bedroom', '2_bedroom']]
df_neighborhood2 = df_neighborhood2.dropna(subset = ['neighborhood.2'])
df_neighborhood2 = df_neighborhood2.rename(columns={'neighborhood.2': 'neighborhood'})

# %%
df_neighborhood2
# Out:
#            neighborhood  studio  1_bedroom  2_bedroom
# 0       Upper West Side  1975.0     2750.0     4350.0
# 1    Bedford-Stuyvesant  1650.0     1975.0     2200.0
# 2              Bushwick  1731.0     2150.0     2100.0
# 3       Upper East Side  1898.0     2395.0     3295.0
# 4          Williamsburg  2491.0     2500.0     2584.0
# ..                  ...     ...        ...        ...
# 200  Van Cortlandt Park     NaN        NaN     1983.0
# 201   Castleton Corners     NaN        NaN     1400.0
# 202  Brooklyn Navy Yard     NaN        NaN     5345.0
# 203    Travis - Chelsea     NaN        NaN     1800.0
# 204            Longwood     NaN        NaN     1377.0
#
# [205 rows x 4 columns]

# %%
df_neighborhood.merge(df_neighborhood1, how='outer', on='neighborhood')
# Out:
#            neighborhood  studio_x  1_bedroom_x  2_bedroom_x  studio_y  \
# 0       Upper West Side    1975.0       2750.0       4350.0    1975.0
# 1    Bedford-Stuyvesant    1650.0       1975.0       2200.0    1650.0
# 2              Bushwick    1731.0       2150.0       2100.0    1731.0
# 3       Upper East Side    1898.0       2395.0       3295.0    1898.0
# 4          Williamsburg    2491.0       2500.0       2584.0    2491.0
# ..                  ...       ...          ...          ...       ...
# 189      Fort Wadsworth       NaN          NaN          NaN       NaN
# 190          Holliswood       NaN          NaN          NaN       NaN
# 191            Huguenot       NaN          NaN          NaN       NaN
# 192       Manor Heights       NaN          NaN          NaN       NaN
# 193          Blissville       NaN          NaN          NaN       NaN
#
#      1_bedroom_y  2_bedroom_y
# 0         2750.0       4350.0
# 1         1975.0       2200.0
# 2         2150.0       2100.0
# 3         2395.0       3295.0
# 4         2500.0       2584.0
# ..           ...          ...
# 189       3350.0       1825.0
# 190       1895.0       2300.0
# 191       1350.0       1850.0
# 192       1200.0       1900.0
# 193       1600.0       1700.0
#
# [194 rows x 7 columns]

# %%
df_merge1 = df_neighborhood.merge(df_neighborhood1, how='outer', on='neighborhood')

# %%
df_merge2 = df_merge1.merge(df_neighborhood2, how='outer', on='neighborhood')
df_combined = df_merge2[['neighborhood', 'studio', '1_bedroom', '2_bedroom']]
df_combined
# Out:
#            neighborhood  studio  1_bedroom  2_bedroom
# 0       Upper West Side  1975.0     2750.0     4350.0
# 1    Bedford-Stuyvesant  1650.0     1975.0     2200.0
# 2              Bushwick  1731.0     2150.0     2100.0
# 3       Upper East Side  1898.0     2395.0     3295.0
# 4          Williamsburg  2491.0     2500.0     2584.0
# ..                  ...     ...        ...        ...
# 211          Grant City     NaN     1200.0     1900.0
# 212          Co-Op City     NaN     1500.0     1575.0
# 213   Castleton Corners     NaN        NaN     1400.0
# 214    Travis - Chelsea     NaN        NaN     1800.0
# 215            Longwood     NaN        NaN     1377.0
#
# [216 rows x 4 columns]

# %%
# %store nyc_df
# Out:
# Stored 'nyc_df' (DataFrame)

# %%
# %store df_combined
# Out:
# Stored 'df_combined' (DataFrame)

# %%
nyc_df = nyc_df[['Neighborhood', 'Borough', 'Latitude', 'Longitude']]

# %%
nyc_df
# Out:
#      Neighborhood        Borough   Latitude  Longitude
# 0       Wakefield          Bronx  40.894705 -73.847201
# 1      Co-op City          Bronx  40.874294 -73.829939
# 2     Eastchester          Bronx  40.887556 -73.827806
# 3       Fieldston          Bronx  40.895437 -73.905643
# 4       Riverdale          Bronx  40.890834 -73.912585
# ..            ...            ...        ...        ...
# 301  Hudson Yards      Manhattan  40.756658 -74.000111
# 302       Hammels         Queens  40.587338 -73.805530
# 303     Bayswater         Queens  40.611322 -73.765968
# 304  Queensbridge         Queens  40.756091 -73.945631
# 305     Fox Hills  Staten Island  40.617311 -74.081740
#
# [306 rows x 4 columns]

# %%
# !pip install folium

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10, 
                         min_zoom=9, max_zoom=15)

# add markers to map
for lat, lon, borough, neighborhood in zip(nyc_df['Latitude'], 
                                           nyc_df['Longitude'], 
                                           nyc_df['Borough'], 
                                           nyc_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=3,
        popup=label,
        weight=2,
        color='#333333',
        fill=True,
        fill_color='#ffb300',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1970da201ee115862aa56ce77e46ba0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1970da201ee115862aa56ce77e46ba0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b1970da201ee115862aa56ce77e46ba0 = L.map(
#                 &quot;map_b1970da201ee115862aa56ce77e46ba0&quot;,
#                 {
#                     center: [40.7127281, -74.0060152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40f0c4559dfdbf0821cbd45a814efc57 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 15, &quot;maxZoom&quot;: 15, &quot;minZoom&quot;: 9, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b1970da201ee115862aa56ce77e46ba0);
#
#
#             var circle_marker_e7b26fe410af25d9be3a746f4de7ed91 = L.circleMarker(
#                 [40.89470517661, -73.84720052054902],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#333333&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffb300&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_b1970da201ee115862aa56ce77e46ba0);
#
#
#         var popup_d0cc1955eb1c65c63f6097b3ccf39677 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_80a89cf4c3de0cabe19b6da18becb588 = $(`&lt;div id=&quot;html_80a89cf4c3de0cabe19b6da18becb588&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wakefield, Bronx&lt;/div&gt;`)[0];
#                 popup_d0cc1955eb1c65c63f6097b3ccf39677.setContent(html_80a89cf4c3de0cabe19b6da18becb588);
#
#
#
#         circle_marker_e7b26fe410af25d9be3a746f4de7ed91.bindPopup(popup_d0cc1955eb1c65c63f6097b3ccf39677)
#         ;
#
#
#
#
#             var circle_marker_813b5ab18444cc6d29da45a4248291ef = L.circleMarker(
#                 [40.87429419303012, -73.82993910812398],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#333333&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffb300&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_b1970da201ee115862aa56ce77e46ba0);
#
#
#         var popup_660a6fe9356100d537b5c398207f1f9e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_14d256b0bac50106a008d6f82408cdcc = $(`&lt;div id=&quot;html_14d256b0bac50106a008d6f82408cdcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Co-op City, Bronx&lt;/div&gt;`)[0];
#                 popup_660a6fe9356100d537b5c398207f1f9e.setContent(html_14d256b0bac50106a008d6f82408cdcc);
#
#
#
#         circle_marker_813b5ab18444cc6d29da45a4248291ef.bindPopup(popup_660a6fe9356100d537b5c398207f1f9e)
#         ;
#
#
#
#
#             var circle_marker_bdfd1dd489535b0abc8548f71d880578 = L.circleMarker(
#                 [40.887555677350775, -73.82780644716412],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#333333&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffb300&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_b1970da201ee115862aa56ce77e46ba0);
#
#
#         var popup_c9d205bc8246fb75eff9fdff0b69d67e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13e54d17bccb3db294a55beaf0332215 = $(`&lt;div id=&quot;html_13e54d17bccb3db294a55beaf0332215&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eastchester, Bronx&lt;/div&gt;`)[0];
#                 popup_c9d205bc8246fb75eff9fdff0b69d67e.setContent(html_13e54d17bccb3db294a55beaf0332215);
#
#
#
#         circle_marker_bdfd1dd489535b0abc8548f71d880578.bindPopup(popup_c9d205bc8246fb75eff9fdff0b69d67e)
#         ;
#
#
#
#
#             var circle_marker_d4a73fe367a6b0cbd76534ee026bc92f = L.circleMarker(
#                 [40.89543742690383, -73.90564259591682],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#333333&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffb300&
